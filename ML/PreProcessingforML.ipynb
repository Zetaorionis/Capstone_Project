# %%
# import via notebook
# !mongoimport --type json -d wine -c ratings --drop --jsonArray ../Resources/clean_wine_data_final.json
# Out:
# 2024-05-06T18:18:47.196-0700	connected to: mongodb://localhost/
# 2024-05-06T18:18:47.197-0700	dropping: wine.ratings
# 2024-05-06T18:18:49.221-0700	76736 document(s) imported successfully. 0 document(s) failed to import.

# %%
# Importing Necessary Libraries
from pymongo import MongoClient
from pprint import pprint
import pandas as pd
import tensorflow as tf

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
mongo.list_database_names()
# Out:
# ['admin',
#  'air_b_and_b',
#  'autosaurus',
#  'classDB',
#  'config',
#  'gardenDB',
#  'local',
#  'met',
#  'uk_food',
#  'wine']

# %%
db = mongo['wine']
db.list_collection_names()
# Out:
# ['ratings']

# %%
#assign the collection to a variable
wine_df = db['ratings']

# %%
cursor = db["ratings"].find({})
json_data = list(cursor)

# %%
wine_df = pd.DataFrame(json_data)
wine_df.head()
# Out:
#                         _id    country  \
# 0  663981777c97be4d34cbc47a         US
# 1  663981777c97be4d34cbc47b         US
# 2  663981777c97be4d34cbc47c  Argentina
# 3  663981777c97be4d34cbc47d         US
# 4  663981777c97be4d34cbc47e         US
#
#                                          description  points  price  \
# 0  Tart and snappy, the flavors of lime flesh and...      87     14
# 1  Much like the regular bottling from 2012, this...      87     65
# 2  Raw black-cherry aromas are direct and simple ...      87     13
# 3  Soft, supple plum envelopes an oaky structure ...      87     19
# 4  Ripe aromas of dark berries mingle with ample ...      87     23
#
#            province             region  \
# 0            Oregon  Willamette Valley
# 1            Oregon  Willamette Valley
# 2  Mendoza Province            Mendoza
# 3        California        Napa Valley
# 4          Virginia           Virginia
#
#                                                title             variety  \
# 0      Rainstorm 2013 Pinot Gris (Willamette Valley)          Pinot Gris
# 1  Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# 2  Gaucho Andino 2011 Winemaker Selection Malbec ...              Malbec
# 3  Kirkland Signature 2011 Mountain Cuvée Caberne...  Cabernet Sauvignon
# 4      Quiévremont 2012 Vin de Maison Red (Virginia)           Red Blend
#
#                winery rating_category       type
# 0           Rainstorm            Good      White
# 1        Sweet Cheeks            Good        Red
# 2       Gaucho Andino            Good        Red
# 3  Kirkland Signature            Good        Red
# 4         Quiévremont            Good  Red Blend

# %%
# Drop id columns
wine_df.drop(columns=['_id', 'description', 'title', 'winery'], inplace=True)

# %%
wine_df
# Out:
#          country  points  price          province             region  \
# 0             US      87     14            Oregon  Willamette Valley
# 1             US      87     65            Oregon  Willamette Valley
# 2      Argentina      87     13  Mendoza Province            Mendoza
# 3             US      87     19        California        Napa Valley
# 4             US      87     23          Virginia           Virginia
# ...          ...     ...    ...               ...                ...
# 76731     France      90     32            Alsace             Alsace
# 76732  Argentina      91     55  Mendoza Province         Uco Valley
# 76733         US      90     35        California        Napa Valley
# 76734      Spain      91     52         Catalonia            Priorat
# 76735     France      90     28            Alsace             Alsace
#
#                   variety rating_category       type
# 0              Pinot Gris            Good      White
# 1              Pinot Noir            Good        Red
# 2                  Malbec            Good        Red
# 3      Cabernet Sauvignon            Good        Red
# 4               Red Blend            Good  Red Blend
# ...                   ...             ...        ...
# 76731          Pinot Gris       Very Good      White
# 76732           Red Blend       Excellent  Red Blend
# 76733           Zinfandel       Very Good        Red
# 76734           Red Blend       Excellent  Red Blend
# 76735          Pinot Gris       Very Good      White
#
# [76736 rows x 8 columns]

# %% [markdown]
# Examine columns for encoding

# %%
wine_df.nunique()
# Out:
# country              7
# points              21
# price              335
# province            62
# region             998
# variety             20
# rating_category      6
# type                 5
# dtype: int64

# %%
wine_df['province'].value_counts()
# Out:
# province
# California            31397
# Washington             7387
# Oregon                 4816
# Tuscany                4225
# Bordeaux               3389
#                       ...
# Nevada                    2
# Northwestern Italy        2
# Iowa                      2
# Kentucky                  1
# Hawaii                    1
# Name: count, Length: 62, dtype: int64

# %%
wine_df['province'].value_counts()[wine_df['province'].value_counts() > 1]
# Out:
# province
# California              31397
# Washington               7387
# Oregon                   4816
# Tuscany                  4225
# Bordeaux                 3389
# Burgundy                 3046
# Mendoza Province         2724
# Piedmont                 2291
# New York                 2223
# Northern Spain           1770
# Alsace                   1444
# Loire Valley             1084
# Provence                 1011
# Catalonia                 968
# Southwest France          872
# Rhône Valley              744
# Veneto                    664
# Sicily & Sardinia         648
# South Australia           623
# Virginia                  544
# Languedoc-Roussillon      481
# Northeastern Italy        466
# France Other              444
# Central Italy             411
# Other                     356
# Central Spain             338
# Champagne                 321
# Lombardy                  300
# Southern Italy            208
# Levante                   201
# Western Australia         200
# Victoria                  175
# Australia Other           148
# British Columbia          134
# Michigan                   87
# Ontario                    65
# Colorado                   60
# Italy Other                46
# Beaujolais                 43
# New South Wales            42
# Tasmania                   39
# Texas                      38
# Galicia                    38
# New Mexico                 34
# Spain Other                32
# Arizona                    29
# Idaho                      21
# Spanish Islands            17
# North Carolina             16
# Pennsylvania               15
# Ohio                       12
# Andalucia                  10
# Missouri                   10
# New Jersey                  8
# Illinois                    6
# Massachusetts               4
# Connecticut                 3
# Nevada                      2
# Northwestern Italy          2
# Iowa                        2
# Name: count, dtype: int64

# %%
# columns to drop: region, province
wine_df.drop(columns=['region', 'province'], inplace=True)

# %% [markdown]
# # columns for encoding: country, variety, rating catagory and type

# %%
#country
countries = []
country_encoding_count = []
counter = 0
for unique in wine_df['country'].unique():
    countries.append(unique)
for country in countries:
    counter += 1
    country_encoding_count.append(counter)

print(countries)
print(country_encoding_count)
# Out:
# ['US', 'Argentina', 'Italy', 'France', 'Australia', 'Spain', 'Canada']
# [1, 2, 3, 4, 5, 6, 7]

# %%
country_dict = dict(zip(countries, country_encoding_count))
country_dict
# Out:
# {'US': 1,
#  'Argentina': 2,
#  'Italy': 3,
#  'France': 4,
#  'Australia': 5,
#  'Spain': 6,
#  'Canada': 7}

# %%
wine_df['country'] = wine_df['country'].map(country_dict)
wine_df.head()
# Out:
#    country  points  price             variety rating_category       type
# 0        1      87     14          Pinot Gris            Good      White
# 1        1      87     65          Pinot Noir            Good        Red
# 2        2      87     13              Malbec            Good        Red
# 3        1      87     19  Cabernet Sauvignon            Good        Red
# 4        1      87     23           Red Blend            Good  Red Blend

# %%
# variety
variety = []
variety_encoding_count = []
counter = 0
for unique in wine_df['variety'].unique():
    variety.append(unique)
for i in variety:
    counter += 1
    variety_encoding_count.append(counter)
variety_dict = dict(zip(variety, variety_encoding_count))
wine_df['variety'] = wine_df['variety'].map(variety_dict)
wine_df.head()
# Out:
#    country  points  price  variety rating_category       type
# 0        1      87     14        1            Good      White
# 1        1      87     65        2            Good        Red
# 2        2      87     13        3            Good        Red
# 3        1      87     19        4            Good        Red
# 4        1      87     23        5            Good  Red Blend

# %%
variety_dict
# Out:
# {'Pinot Gris': 1,
#  'Pinot Noir': 2,
#  'Malbec': 3,
#  'Cabernet Sauvignon': 4,
#  'Red Blend': 5,
#  'Merlot': 6,
#  'White Blend': 7,
#  'Sauvignon Blanc': 8,
#  'Riesling': 9,
#  'Chardonnay': 10,
#  'Sangiovese': 11,
#  'Cabernet Franc': 12,
#  'Bordeaux-style Red Blend': 13,
#  'Zinfandel': 14,
#  'Rosé': 15,
#  'Nebbiolo': 16,
#  'Rhône-style Red Blend': 17,
#  'Syrah': 18,
#  'Sparkling Blend': 19,
#  'Tempranillo': 20}

# %%
# rating_category_dict
rating_category = []
rating_category_encoding_count = []
counter = 0
for unique in wine_df['rating_category'].unique():
    rating_category.append(unique)
for i in variety:
    counter += 1
    rating_category_encoding_count.append(counter)
rating_category_dict = dict(zip(rating_category, rating_category_encoding_count))
wine_df['rating_category'] = wine_df['rating_category'].map(rating_category_dict)
wine_df.head()
# Out:
#    country  points  price  variety  rating_category       type
# 0        1      87     14        1                1      White
# 1        1      87     65        2                1        Red
# 2        2      87     13        3                1        Red
# 3        1      87     19        4                1        Red
# 4        1      87     23        5                1  Red Blend

# %%
# type
type = []
type_encoding_count = []
counter = 0
for unique in wine_df['type'].unique():
    type.append(unique)
for i in variety:
    counter += 1
    type_encoding_count.append(counter)
type_category_dict = dict(zip(type, type_encoding_count))
wine_df['type'] = wine_df['type'].map(type_category_dict)
wine_df.head()
# Out:
#    country  points  price  variety  rating_category  type
# 0        1      87     14        1                1     1
# 1        1      87     65        2                1     2
# 2        2      87     13        3                1     2
# 3        1      87     19        4                1     2
# 4        1      87     23        5                1     3
